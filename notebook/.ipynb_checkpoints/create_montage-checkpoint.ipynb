# %%
import pickle
import torch
import mne
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = torch.load("data/EEG_ImageNet/preprocessing/5-95/eeg_5_95_std_dataset_snr_10.0.pth")
len(data["LR"]["train"])
# Out:
# 7179

# %% [markdown]
# ## 128-channel system

# %%
df = pd.read_csv("data/EEG_ImageNet/ch_name.csv")
ch_name_list = df["ch_name"].tolist()

# %%
path = "data/EEG_ImageNet/original/eeg_5_95_std.pth"

data = np.array(torch.load(path)["dataset"][0]["eeg"], dtype = np.float32)
data.shape
# Out:
# (128, 500)

# %%
info = mne.create_info(ch_name_list, 1000, ch_types = "eeg")
montage = mne.channels.make_standard_montage('standard_1005')
pos = montage.get_positions()
channels_to_remove = [ch for ch in pos["ch_pos"] if ch not in ch_name_list]

for ch in channels_to_remove:
    del pos["ch_pos"][ch]

# %%
pos
# Out:
# {'ch_pos': OrderedDict([('Fp1', array([-0.0294367,  0.0839171, -0.00699  ])),
#               ('Fpz', array([ 0.0001123,  0.088247 , -0.001713 ])),
#               ('Fp2', array([ 0.0298723,  0.0848959, -0.00708  ])),
#               ('AF7', array([-0.0548397,  0.0685722, -0.01059  ])),
#               ('AF3', array([-0.0337007,  0.0768371,  0.021227 ])),
#               ('AF4', array([0.0357123, 0.0777259, 0.021956 ])),
#               ('AF8', array([ 0.0557433,  0.0696568, -0.010755 ])),
#               ('F9', array([-0.0701019,  0.0416523, -0.049952 ])),
#               ('F7', array([-0.0702629,  0.0424743, -0.01142  ])),
#               ('F5', array([-0.0644658,  0.0480353,  0.016921 ])),
#               ('F3', array([-0.0502438,  0.0531112,  0.042192 ])),
#               ('F1', array([-0.0274958,  0.0569311,  0.060342 ])),
#               ('Fz', array([0.0003122, 0.058512 , 0.066462 ])),
#               ('F2', array([0.0295142, 0.0576019, 0.05954  ])),
#               ('F4', array([0.0518362, 0.0543048, 0.040814 ])),
#               ('F6', array([0.0679142, 0.0498297, 0.016367 ])),
#               ('F8', array([ 0.0730431,  0.0444217, -0.012    ])),
#               ('F10', array([ 0.0721141,  0.0420667, -0.050452 ])),
#               ('FT9', array([-0.0840759,  0.0145673, -0.050429 ])),
#               ('FT7', array([-0.080775 ,  0.0141203, -0.011135 ])),
#               ('FC5', array([-0.0772149,  0.0186433,  0.02446  ])),
#               ('FC3', array([-0.0601819,  0.0227162,  0.055544 ])),
#               ('FC1', array([-0.0340619,  0.0260111,  0.079987 ])),
#               ('FC2', array([0.0347841, 0.0264379, 0.078808 ])),
#               ('FC4', array([0.0622931, 0.0237228, 0.05563  ])),
#               ('FC6', array([0.0795341, 0.0199357, 0.024438 ])),
#               ('FT8', array([ 0.0818151,  0.0154167, -0.01133  ])),
#               ('FT10', array([ 0.0841131,  0.0143647, -0.050538 ])),
#               ('T7', array([-0.0841611, -0.0160187, -0.009346 ])),
#               ('C5', array([-0.0802801, -0.0137597,  0.02916  ])),
#               ('C3', array([-0.0653581, -0.0116317,  0.064358 ])),
#               ('C1', array([-0.036158 , -0.0099839,  0.089752 ])),
#               ('Cz', array([ 0.0004009, -0.009167 ,  0.100244 ])),
#               ('C2', array([ 0.037672 , -0.0096241,  0.088412 ])),
#               ('C4', array([ 0.0671179, -0.0109003,  0.06358  ])),
#               ('C6', array([ 0.0834559, -0.0127763,  0.029208 ])),
#               ('T8', array([ 0.0850799, -0.0150203, -0.00949  ])),
#               ('TP9', array([-0.0856192, -0.0465147, -0.045707 ])),
#               ('TP7', array([-0.0848302, -0.0460217, -0.007056 ])),
#               ('CP5', array([-0.0795922, -0.0465507,  0.030949 ])),
#               ('CP3', array([-0.0635562, -0.0470088,  0.065624 ])),
#               ('CP1', array([-0.0355131, -0.0472919,  0.091315 ])),
#               ('CPz', array([ 0.0003858, -0.047318 ,  0.099432 ])),
#               ('CP2', array([ 0.0383838, -0.0470731,  0.090695 ])),
#               ('CP4', array([ 0.0666118, -0.0466372,  0.06558  ])),
#               ('CP6', array([ 0.0833218, -0.0461013,  0.031206 ])),
#               ('TP8', array([ 0.0855488, -0.0455453, -0.00713  ])),
#               ('TP10', array([ 0.0861618, -0.0470353, -0.045869 ])),
#               ('P9', array([-0.0730093, -0.0737657, -0.040998 ])),
#               ('P7', array([-0.0724343, -0.0734527, -0.002487 ])),
#               ('P5', array([-0.0672723, -0.0762907,  0.028382 ])),
#               ('P3', array([-0.0530073, -0.0787878,  0.05594  ])),
#               ('P1', array([-0.0286203, -0.0805249,  0.075436 ])),
#               ('Pz', array([ 0.0003247, -0.081115 ,  0.082615 ])),
#               ('P2', array([ 0.0319197, -0.0804871,  0.076716 ])),
#               ('P4', array([ 0.0556667, -0.0785602,  0.056561 ])),
#               ('P6', array([ 0.0678877, -0.0759043,  0.028091 ])),
#               ('P8', array([ 0.0730557, -0.0730683, -0.00254  ])),
#               ('P10', array([ 0.0738947, -0.0743903, -0.04122  ])),
#               ('PO9', array([-0.0549104, -0.0980448, -0.035465 ])),
#               ('PO7', array([-0.0548404, -0.0975279,  0.002792 ])),
#               ('PO3', array([-0.0365114, -0.1008529,  0.037167 ])),
#               ('POz', array([ 0.0002156, -0.102178 ,  0.050608 ])),
#               ('PO4', array([ 0.0367816, -0.1008491,  0.036397 ])),
#               ('PO8', array([ 0.0556666, -0.0976251,  0.00273  ])),
#               ('PO10', array([ 0.0549876, -0.0980911, -0.035541 ])),
#               ('O1', array([-0.0294134, -0.112449 ,  0.008839 ])),
#               ('Oz', array([ 1.07600e-04, -1.14892e-01,  1.46570e-02])),
#               ('O2', array([ 0.0298426, -0.112156 ,  0.0088   ])),
#               ('I1', array([-0.0298184, -0.11457  , -0.029216 ])),
#               ('Iz', array([ 4.50000e-06, -1.18565e-01, -2.30780e-02])),
#               ('I2', array([ 0.0297416, -0.11426  , -0.029256 ])),
#               ('AFp5h', array([-0.0279857,  0.0824591,  0.002702 ])),
#               ('AFp1h', array([-0.0059317,  0.086878 ,  0.0162   ])),
#               ('AFp2h', array([0.0071053, 0.087074 , 0.016469 ])),
#               ('AFp6h', array([0.0286443, 0.0829759, 0.002828 ])),
#               ('FFT9h', array([-0.0790669,  0.0280813, -0.031253 ])),
#               ('FFT7h', array([-0.0744999,  0.0313003,  0.004846 ])),
#               ('FFC5h', array([-0.0652379,  0.0364282,  0.036144 ])),
#               ('FFC3h', array([-0.0444098,  0.0407622,  0.06169  ])),
#               ('FFC1h', array([-0.0154238,  0.04366  ,  0.077682 ])),
#               ('FFC2h', array([0.0175922, 0.044054 , 0.077788 ])),
#               ('FFC4h', array([0.0458532, 0.0416228, 0.060647 ])),
#               ('FFC6h', array([0.0671281, 0.0377998, 0.035296 ])),
#               ('FFT8h', array([0.0780531, 0.0329817, 0.004483 ])),
#               ('FFT10h', array([ 0.0800971,  0.0285137, -0.031338 ])),
#               ('FTT9h', array([-0.084125 , -0.0018467, -0.029794 ])),
#               ('FTT7h', array([-0.082355 ,  0.0008263,  0.008579 ])),
#               ('FCC5h', array([-0.074692 ,  0.0043033,  0.045307 ])),
#               ('FCC3h', array([-0.0510509,  0.0071772,  0.074377 ])),
#               ('FCC1h', array([-0.018219 ,  0.0090941,  0.092529 ])),
#               ('FCC2h', array([0.018787 , 0.0092479, 0.091562 ])),
#               ('FCC4h', array([0.0518851, 0.0077978, 0.073507 ])),
#               ('FCC6h', array([0.077002 , 0.0053357, 0.04535  ])),
#               ('FTT8h', array([0.083888 , 0.0019457, 0.008501 ])),
#               ('FTT10h', array([ 0.084123 , -0.0018083, -0.029638 ])),
#               ('TTP7h', array([-0.0855651, -0.0306287,  0.011153 ])),
#               ('CCP5h', array([-0.0764071, -0.0297307,  0.049217 ])),
#               ('CCP3h', array([-0.0529281, -0.0289058,  0.080304 ])),
#               ('CCP1h', array([-0.0183541, -0.0283219,  0.09822  ])),
#               ('CCP2h', array([ 0.0202199, -0.0281481,  0.098172 ])),
#               ('CCP4h', array([ 0.0551139, -0.0283862,  0.080474 ])),
#               ('CCP6h', array([ 0.0790059, -0.0289863,  0.049628 ])),
#               ('TTP8h', array([ 0.0859999, -0.0298203,  0.011248 ])),
#               ('TPP9h', array([-0.0781602, -0.0607567, -0.023824 ])),
#               ('TPP7h', array([-0.0766802, -0.0608317,  0.01288  ])),
#               ('CPP5h', array([-0.0681152, -0.0629747,  0.047252 ])),
#               ('CPP3h', array([-0.0469142, -0.0646908,  0.075296 ])),
#               ('CPP1h', array([-0.0158202, -0.0655999,  0.091164 ])),
#               ('CPP2h', array([ 0.0194198, -0.065595 ,  0.092405 ])),
#               ('CPP4h', array([ 0.0506738, -0.0644822,  0.07613  ])),
#               ('CPP6h', array([ 0.0710958, -0.0626243,  0.047328 ])),
#               ('TPP8h', array([ 0.0785198, -0.0604323,  0.012902 ])),
#               ('TPP10h', array([ 0.0789027, -0.0609553, -0.023805 ])),
#               ('PPO9h', array([-0.0645973, -0.0876558, -0.019014 ])),
#               ('PPO5h', array([-0.0540103, -0.0898988,  0.037332 ])),
#               ('PPO1h', array([-0.0120474, -0.0926069,  0.065508 ])),
#               ('PPO2h', array([ 0.0139226, -0.092694 ,  0.066958 ])),
#               ('PPO6h', array([ 0.0546087, -0.0896402,  0.037035 ])),
#               ('PPO10h', array([ 0.0650137, -0.0878062, -0.018952 ])),
#               ('POO9h', array([-0.0428624, -0.108073 , -0.013151 ])),
#               ('POO10h', array([ 0.0438946, -0.109127 , -0.01317  ])),
#               ('OI1h', array([-0.0148504, -0.117987 , -0.00692  ])),
#               ('OI2h', array([ 0.0150946, -0.118018 , -0.006933 ])),
#               ('AFp1', array([-0.0122417,  0.0861941,  0.014188 ])),
#               ('AFp2', array([0.0136223, 0.0867579, 0.015302 ])),
#               ('POO1', array([-0.0136644, -0.109266 ,  0.032856 ])),
#               ('POO2', array([ 0.0136506, -0.109106 ,  0.030936 ]))]),
#  'coord_frame': 'mri',
#  'nasion': array([ 0.00146763,  0.08506715, -0.03483611], dtype=float32),
#  'lpa': array([-0.08061612, -0.02908875, -0.04131077], dtype=float32),
#  'rpa': array([ 0.08436285, -0.02850276, -0.04127743], dtype=float32),
#  'hsp': None,
#  'hpi': None}

# %%
new_montage = mne.channels.make_dig_montage(
    ch_pos = pos["ch_pos"],
    lpa = pos["lpa"],
    rpa = pos["rpa"],
    hsp = pos["hsp"],
    hpi = pos["hpi"],
    coord_frame = pos["coord_frame"],
    nasion = pos["nasion"]
)

# %%
new_montage.plot()

# %%
with open("data/Montage/128_ch_system.pkl", 'wb') as f:
    pickle.dump(new_montage, f)

# %%
evoked = mne.EvokedArray(data, info)
evoked.set_montage(new_montage)
# Out:
# <Evoked | '' (average, N=1), 0 – 0.499 s, baseline off, 128 ch, ~674 kB>

# %%
fig, axs = plt.subplots(nrows=1, ncols=8, figsize=(20, 4))
for i in range(8):
    tmp_data = evoked.data[:, i*25:(i+1)*25]
    topo_data = np.mean(tmp_data, axis=1)
    topo_data = (topo_data - np.mean(topo_data)) / np.std(topo_data)
#     topo_data = 2 * (topo_data - np.min(topo_data)) / (np.max(topo_data) - np.min(topo_data)) - 1
    im, cn = mne.viz.plot_topomap(
        topo_data, evoked.info, show = False, cmap = 'coolwarm',
        sensors = True, res = 1000, axes=axs[i], size = 2, vlim = (-1, 1)
    )
    axs[i].set_title('%d-%d ms' % (i*100, (i+1)*100))
cax = fig.add_axes([0.92, 0.33, 0.005, 0.4])
fig.colorbar(im, cax=cax)
# plt.savefig("128.jpg")

# %% [markdown]
# ## 8-channel system

# %%
ch_name_list = ["Fp1", "Fp2", "Fz", "T7", "T8", "Pz", "O1", "O2"]

info = mne.create_info(ch_name_list, 1000, ch_types = "eeg")
montage = mne.channels.make_standard_montage('biosemi32')
pos = montage.get_positions()
channels_to_remove = [ch for ch in pos["ch_pos"] if ch not in ch_name_list]

for ch in channels_to_remove:
    del pos["ch_pos"][ch]

# %%
pos
# Out:
# {'ch_pos': OrderedDict([('Fp1',
#                array([-0.02933873,  0.09029533, -0.00331545])),
#               ('T7', array([-0.09494213, -0.        , -0.00331545])),
#               ('Pz',
#                array([ 4.18445162e-18, -6.83372810e-02,  6.59925452e-02])),
#               ('O1', array([-0.02933873, -0.09029533, -0.00331545])),
#               ('O2', array([ 0.02933873, -0.09029533, -0.00331545])),
#               ('T8', array([ 0.09494213,  0.        , -0.00331545])),
#               ('Fp2', array([ 0.02933873,  0.09029533, -0.00331545])),
#               ('Fz',
#                array([4.18445162e-18, 6.83372810e-02, 6.59925452e-02]))]),
#  'coord_frame': 'unknown',
#  'nasion': array([ 5.27205792e-18,  8.60992398e-02, -4.01487349e-02]),
#  'lpa': array([-0.08609924, -0.        , -0.04014873]),
#  'rpa': array([ 0.08609924,  0.        , -0.04014873]),
#  'hsp': None,
#  'hpi': None}

# %%
new_montage = mne.channels.make_dig_montage(
    ch_pos = pos["ch_pos"],
    lpa = pos["lpa"],
    rpa = pos["rpa"],
    hsp = pos["hsp"],
    hpi = pos["hpi"],
    coord_frame = pos["coord_frame"],
    nasion = pos["nasion"]
)

# %%
new_montage.plot()

# %%
with open("data/Montage/8_ch_system.pkl", 'wb') as f:
    pickle.dump(new_montage, f)

# %%
sample = np.concatenate(
    [data[i, :].reshape(1, -1) for i in [0, 2, 12, 28, 36, 53, 66, 68]],
    axis = 0
)

evoked = mne.EvokedArray(sample, info)
evoked.set_montage(new_montage)
# Out:
# <Evoked | '' (average, N=1), 0 – 0.499 s, baseline off, 8 ch, ~49 kB>

# %%
fig, axs = plt.subplots(nrows=1, ncols=10, figsize=(20, 3))
for i in range(10):
    tmp_data = evoked.data[:, i*25:(i+1)*25]
    topo_data = np.mean(tmp_data, axis=1)
    topo_data = (topo_data - np.mean(topo_data)) / np.std(topo_data)
#     topo_data = 2 * (topo_data - np.min(topo_data)) / (np.max(topo_data) - np.min(topo_data)) - 1
    im, cn = mne.viz.plot_topomap(
        topo_data, evoked.info, show = False, cmap = 'coolwarm', sensors = True,
        res = 1000, axes=axs[i], size = 1, vlim = (-1, 1))
    axs[i].set_title('%d-%d ms' % (i*100, (i+1)*100))
cax = fig.add_axes([0.92, 0.33, 0.005, 0.4])
fig.colorbar(im, cax=cax)
# plt.savefig("8.jpg")
